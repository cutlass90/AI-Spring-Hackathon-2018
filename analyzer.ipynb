# %%
import pandas as pd
from polyglot.text import Text
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from user_agents import parse
from multiprocessing import Pool
from polyglot.detect import Detector
from collections import Counter

# %%
def apply(func, list_):
    with Pool(8) as pool:
        res = pool.map(func, list_)
    return pd.Series(res)

# %%
path = '../data/train.csv'

# %%
df = pd.read_csv(path)

# %%
df_test = pd.read_csv('../data/test.csv')
# Out:
# /home/nazar/AI_Spring_hackathon_2018/env/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['comment_id', 'company_id', 'user_id', 'product_id', 'comment',
#        'rating', 'date_created', 'user_date_created', 'user_ip', 'user_agent',
#        'is_fake'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    comment_id  company_id  user_id  product_id  \
# 0           1     2169053    91933         6.0
# 1           2      709306    91933         2.0
# 2           3       35287    91933         NaN
# 3           4     1778322    91933         1.0
# 4           5     2821533    91933         NaN
# 5           6     2770517    91933         NaN
# 6           7     2686753    91933         5.0
# 7           8     2686383    91951         4.0
# 8           9     2294801    91962       140.0
# 9          10     1879360    91989         NaN
#
#                                              comment  rating  \
# 0  компания не выполнила заказ без  обьяснения пр...       1
# 1  Впервые встретился такой професиональный, отве...       5
# 2  Несерйозная, некоректная менеджер інтернет маг...       1
# 3   Не рекомендую. Не отвечают, не выполняют заказы.       1
# 4  На письма не отвечают, заказы не выполняют. Не...       1
# 5  я заказывала каталог с ценами по купальникам н...       1
# ...

# %%
# df = df.join(df.groupby(['company_id']).is_fake.mean().rename('company_id_mean'), on='company_id')
df.groupby(['product_id']).is_fake.sum()
# Out:
# product_id
# 1.0        False
# 2.0        False
# 4.0        False
# 5.0        False
# 6.0        False
# 7.0        False
# 8.0        False
# 9.0        False
# 10.0       False
# 11.0       False
# 14.0       False
# 17.0       False
# 18.0       False
# 21.0       False
# 23.0       False
# 24.0       False
# 26.0       False
# 27.0       False
# 29.0       False
# 30.0       False
# 31.0       False
# 32.0       False
# 35.0       False
# 38.0       False
# 40.0       False
# 42.0       False
# 45.0       False
# 47.0       False
# 48.0       False
# 49.0       False
#            ...
# 10384.0    False
# 10386.0    False
# 10393.0    False
# 10398.0    False
# 10399.0    False
# 10409.0    False
# 10414.0    False
# 10435.0    False
# 10442.0    False
# 10452.0    False
# 10454.0    False
# 10467.0    False
# 10469.0    False
# 10485.0    False
# 10496.0    False
# 10505.0    False
# 10510.0    False
# 10512.0    False
# 10517.0    False
# 10520.0    False
# 10531.0    False
# ...

# %%
a
# Out:
# company_id
# 7          0.0
# 10         0.0
# 21         0.0
# 28         0.0
# 70         0.0
# 71         0.0
# 107        0.0
# 113        0.0
# 122        0.0
# 131        0.0
# 153        0.0
# 168        0.0
# 203        0.0
# 233        0.0
# 242        0.0
# 297        0.0
# 298        0.0
# 322        0.0
# 413        0.0
# 465        0.0
# 494        0.0
# 516        0.0
# 560        0.0
# 580        0.0
# 634        0.0
# 661        0.0
# 663        0.0
# 670        0.0
# 685        0.0
# 714        0.0
#           ...
# 2899191    0.0
# 2899213    0.0
# 2899236    0.0
# 2899538    0.0
# 2899796    0.0
# 2899808    0.0
# 2899837    0.0
# 2899948    0.0
# 2900074    0.0
# 2900138    0.0
# 2900192    0.0
# 2900282    0.0
# 2900792    0.0
# 2900852    0.0
# 2901001    0.0
# 2901083    0.0
# 2901450    0.0
# 2901839    0.0
# 2902253    0.0
# 2902285    0.0
# 2902387    0.0
# 2902450    0.0
# 2902716    0.0
# 2902793    0.0
# 2903619    0.0
# 2904320    0.0
# 2905839    0.0
# ...

# %%
# Out:
# company_id
# 606394     319.0
# 1017614    318.0
# 1124489    262.0
# 2085178    312.0
# 2374031    319.0
# 2375911    309.0
# 2648363    326.0
# 2679293    320.0
# 2727931    320.0
# 2801516    312.0
# Name: is_fake, dtype: float64

# %%
# Out:
# {1441792: 0.0,
#  1966085: 0.0,
#  7: 0.0,
#  10: 0.0,
#  1966091: 0.0,
#  393228: 0.0,
#  2359313: 0.0,
#  1095495: 0.0,
#  262164: 0.0,
#  21: 0.0,
#  152921: 0.0,
#  28: 0.0,
#  1048605: 0.0,
#  1048607: 0.0,
#  2701639: 0.0,
#  131107: 0.0,
#  327686: 0.0,
#  1004892: 0.0,
#  1441799: 0.0,
#  917549: 0.0,
#  2708829: 0.0,
#  524340: 0.0,
#  262197: 0.0,
#  2228279: 0.0,
#  393272: 0.0,
#  1441852: 0.0,
#  262205: 0.0,
#  524352: 0.0,
#  70: 0.0,
#  71: 0.0,
#  2228297: 0.0,
#  1114125: 0.0,
#  786514: 0.0,
#  262227: 0.0,
#  1966166: 0.0,
#  1048664: 0.0,
#  1441883: 0.0,
#  262236: 0.0,
#  2359391: 0.0,
#  1835104: 0.0,
#  2228321: 0.0,
#  393314: 0.0,
#  2359398: 0.0,
#  655463: 0.0,
#  2359401: 0.0,
#  107: 0.0,
#  113: 0.0,
#  1835125: 0.0,
#  1441910: 0.0,
#  393336: 0.0,
#  2490489: 0.0,
#  122: 0.0,
#  1179771: 0.0,
#  2228348: 0.0,
#  2621570: 0.0,
#  131: 0.0,
#  2031638: 0.0,
#  917642: 0.0,
#  2378668: 0.0,
#  1835148: 0.0,
#  349549: 0.0,
#  1966226: 0.0,
# ...

# %%
df[df.company_id_mean > 0.5].head()
# Out:
#        comment_id  company_id  user_id  product_id  \
# 6115         7157     1555503   176046      6096.0
# 6839         7985     1017614   186336      7376.0
# 7845         9135     2679293   200067      8072.0
# 17714       20418     1017614   320498     17853.0
# 18711       21529     2679293   324930         NaN
#
#                                                  comment  rating  \
# 6115                         Отклонили безпричинно заказ       1
# 6839                  Молодцы.Все  быстро и качественно.       5
# 7845   Заказ был принят, но через нескольких дней ожи...       3
# 17714                       Хороший магазин, рекомендую.       4
# 18711   .Товар в отвратительном состоянии.Еще и менед...       1
#
#               date_created    user_date_created         user_ip  \
# 6115   2016-11-03 09:24:30  2010-11-02 20:19:49    31.129.88.38
# 6839   2017-08-08 01:16:46  2010-12-01 14:11:32   185.137.18.61
# 7845   2017-10-05 16:46:12  2011-01-13 10:37:17  91.124.243.140
# ...

# %%
print(len(df[df.is_fake==True].company_id.unique()), len(df[df.is_fake==False].company_id.unique()))
# Out:
# 354 60497

# %%
print(len(df[df.is_fake==True].user_id.unique()), len(df[df.is_fake==False].user_id.unique()))
# Out:
# 796 700323

# %%
print(len(df[df.is_fake==True].product_id.unique()), len(df[df.is_fake==False].product_id.unique()))
# Out:
# 2307 671197

# %%
plt.hist(df.rating, bins=5)
plt.show()

# %% [markdown]
# ## Language

# %%
def foo(x):
    try:
        lang = Detector(x).language.name
        if lang not in ['Russian', 'Ukrainian']:
            lang = 'unk'
        
    except:
        lang = 'unk'
    return lang

# %%
# language = apply(foo, df.comment.tolist())

# %%
languages_train = apply(foo, df.comment.tolist())
# Out:
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# ...

# %%
languages_train.value_counts()
# Out:
# Russian      1152388
# Ukrainian     112329
# unk            16782
# dtype: int64

# %% [markdown]
# ## comments length

# %%
tokenized = [Text(comment) for comment in df.comment[:10000]]

# %%
lens = [len(text.tokens) for text in tokenized]
# Out:
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# ...

# %%
plt.hist(lens, bins=50)
plt.show()

# %%
vectorizer = TfidfVectorizer()

# %%
a = vectorizer.fit_transform(df.comment[:1000])

# %%
# Out:
# <1000x4099 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14374 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Date time analises

# %%
from dateutil import parser
def str2unix(text):
    return parser.parse(text).timestamp()

# %%
df['date_created_unix'] = df.date_created.apply(str2unix)

# %%
df['user_date_created_unix'] = df.user_date_created.apply(str2unix)

# %%
plt.hist(df['date_created_unix'], bins=100)
plt.title('date_created_unix')
plt.show()

# %%
plt.hist(df['user_date_created_unix'], bins=100)
plt.title('user_date_created_unix')
plt.show()

# %%
plt.hist((df.date_created_unix - df.user_date_created_unix)[df.is_fake==True], bins=50, range=[0, 1e7])
plt.title('Period from create acc to create FAKE comments')
plt.show()

# %%
plt.hist((df.date_created_unix - df.user_date_created_unix)[df.is_fake==False], bins=50, range=[0, 1e7])
plt.title('Period from create acc to create TRUE comments')
plt.show()

# %%
df.join(df.groupby(['product_id']).date_created_unix.min().rename('first_date_created_unix'), on='product_id')
# Out:
#          comment_id  company_id   user_id  product_id  \
# 0                 1     2169053     91933         6.0
# 1                 2      709306     91933         2.0
# 2                 3       35287     91933         NaN
# 3                 4     1778322     91933         1.0
# 4                 5     2821533     91933         NaN
# 5                 6     2770517     91933         NaN
# 6                 7     2686753     91933         5.0
# 7                 8     2686383     91951         4.0
# 8                 9     2294801     91962       140.0
# 9                10     1879360     91989         NaN
# 10               11     1879923     92038       534.0
# 11               12       90938     92038       115.0
# 12               14     2704861     92188         NaN
# 13               15      151956     92225        23.0
# 14               18     2339730     92277         NaN
# 15               19     1675176     92277       607.0
# ...

# %%
print('Number of unique companies that have Fake comments = ', len(df.company_id[df.is_fake==True].unique()))
print('Number of unique companies that have REAL comments = ', len(df.company_id[df.is_fake==False].unique()))
# Out:
# Number of unique companies that have Fake comments =  354
# Number of unique companies that have REAL comments =  60497
